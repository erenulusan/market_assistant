# %% [markdown]
# * Scraperlarda alt kategorileri siteden çektiğimiz için bazi değişiklikler gösterebiliyor. Bunların unique idlerine bakıp hepsini tek tip şeklinde maplyeceğiz

# %%
import sqlite3
from pathlib import Path
import unicodedata

import pandas as pd

# %%
project_root = Path.cwd().parents[0]
db_path = project_root / "data" / "market.db"


conn = sqlite3.connect(db_path)
conn

# %%
df = pd.read_sql("SELECT * FROM products;", conn)
df.head()
# Out:
#    id    site   top_category subcategory                  name  price  \
# 0   1  migros  Meyve - Sebze       meyve  Mandalina Naturel Kg    NaN
# 1   2  migros  Meyve - Sebze       meyve              Limon Kg  69.95
# 2   3  migros  Meyve - Sebze       meyve          Muz Yerli Kg  79.95
# 3   4  migros  Meyve - Sebze       meyve          Muz İthal Kg  89.95
# 4   5  migros  Meyve - Sebze       meyve           Portakal Kg    NaN
#
#    discounted_price
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8234 entries, 0 to 8233
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                8234 non-null   int64
#  1   site              8234 non-null   object
#  2   top_category      8234 non-null   object
#  3   subcategory       8234 non-null   object
#  4   name              8234 non-null   object
#  5   price             5662 non-null   float64
#  6   discounted_price  4093 non-null   float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 450.4+ KB

# %%
df[df["site"]=="getir"]["subcategory"].unique()
# Out:
# array(['meyve', 'sebze', 'Kırmızı Et', 'Beyaz Et',
#        'Balık ve Deniz Ürünleri', 'Sos', 'Zeytinyağı', 'Sıvı Yağ',
#        'konserve', 'Makarna', 'pirinç', 'bulgur', 'bakliyat', 'Salça',
#        'un', 'şeker', 'çorba', 'baharat', 'pasta malzemeleri', 'Tatlı',
#        'kuruyemiş', 'cips', 'Çikolata', 'gofret', 'kek', 'bisküvi',
#        'Kraker', 'Bar', 'çocuklara özel', 'Sakız & Şekerleme',
#        'Paylaşımlık & Draje', 'Sürülebilir', 'Su', 'buz', 'gazlı i̇çecek',
#        'Maden Suyu', 'ayran & kefir', 'Soğuk Çay', 'Meyve Suyu', 'kahve',
#        'çay', 'enerji i̇çeceği', 'fonksiyonel i̇çecekler'], dtype=object)

# %%
df[df["site"]=="migros"]["subcategory"].unique()
# Out:
# array(['meyve', 'sebze', 'Beyaz Et', 'Balık ve Deniz Ürünleri',
#        'et şarküteri', 'Makarna', 'bakliyat', 'Sıvı Yağ',
#        'tuz, baharat, harç', 'bulyon', 'konserve', 'Sos', 'un', 'şeker',
#        'özel beslenme ürünleri', 'kuru meyve', 'kuruyemiş', 'cips',
#        'çikolata', 'gofret', 'bar', 'bisküvi', 'kek', 'Kraker',
#        'mısır ve pirinç patlağı', 'Sakız & Şekerleme', 'gazlı i̇çecek',
#        'gazsız i̇çecek', 'çay', 'kahve', 'Su', 'Maden Suyu'], dtype=object)

# %%
conn.close()
